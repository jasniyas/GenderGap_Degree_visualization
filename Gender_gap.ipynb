# %% [markdown]
# # Visualizing The Gender Gap In College Degrees
#
# ## Gender gap across STEM degrees

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(20, 4))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# ## Gender gap across all degrees
#
# * Column 1: STEM degrees
# * Column 2: Liberal arts degrees
# * Column 3: All other degrees

# %%
women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

# %%
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
fig = plt.figure(figsize=(18,25))

## Generate first column of line charts. STEM degrees.
for sp in range(0,18,3):
    cat_index=int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    # Generate line graph representing data points.
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[cat_index]], c=cb_orange, label='Men', linewidth=3)
    # Remove the plot spines.
    for key, spine in ax.spines.items(): 
        spine.set_visible(False)
    # set X and Y axis limits.
    ax.set_xlim(1968, 2011) 
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index]) # Plot title
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    ax.set_yticks([0,100]) # Display specific Y-axis values.
    ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3) # generate a horizontal line across an entire subplot.
    # Display legend as line labels to declutter.
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom="on")
    
## Generate second column of line charts. Liberal arts degrees.    
for sp in range(2,16,3):
    lib_index=int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[lib_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[lib_index]], c=cb_orange, label='Men', linewidth=3)
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[lib_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3)
    
    if sp == 2:
        ax.text(2005, 20, 'Men')
        ax.text(2005, 75, 'Women')
    elif sp == 14:
        ax.text(2005, 55, 'Men')
        ax.text(2005, 40, 'Women')
        ax.tick_params(labelbottom="on")
    
## Generate third column of line charts. Other degrees.
for sp in range(3,19,3):
    other_index=int((sp-3)/3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[other_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[other_index]], c=cb_orange, label='Men', linewidth=3)
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[other_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3) 
    
    if sp == 3:
        ax.text(2005, 20, 'Men')
        ax.text(2003, 90, 'Women')
    elif sp == 18:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 35, 'Women')
        ax.tick_params(labelbottom="on")

# Export all plots contained in the figure as a single image file.       
plt.savefig("gender_degrees.png")        
# Show the plot.
plt.show()
